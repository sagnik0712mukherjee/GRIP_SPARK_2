# %% [markdown]
# #### TASK:
# We have to build a decision tree that can effectively make suitable classifications, accurately, based on graphical visualizations.

# %% [markdown]
# #### APPROACH:
# We could define the task assigned into two parts. Part one could comprise of a Decision Tree model that trains itself based on the provided data and make predictions while the second part could contain a more diverse function that enables us to plot the tree for any data. In this, we could define a function that takes the input of the input and target variables and directly plots the graph and makes classification based predictions. We can load iris as an in-built dataset but since we have access to the csv file in the local system directory, we will import the dataset from the local directory itself.

# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder as le
# %matplotlib inline

# %%
iris = pd.read_csv('iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris['Species'] = le.fit_transform(iris['Species'], iris['Species'])
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
inputs = iris.drop(iris[['Id', 'Species']], axis =1)
inputs
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
target = iris[['Species']]
target
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
dec_tree = tree.DecisionTreeClassifier(random_state = 0)

# %%
classifier = dec_tree.fit(inputs, target)

# %%
plt.figure(figsize=(20,15))
tree.plot_tree(classifier, filled = True)
# Out:
# [Text(558.0, 747.4499999999999, 'X[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 611.55, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 611.55, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 475.65, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 339.74999999999994, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 203.8499999999999, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 339.74999999999994, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 203.8499999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 203.8499999999999, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(515.0769230769231, 67.94999999999993, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(686.7692307692307, 67.94999999999993, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(944.3076923076923, 475.65, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(858.4615384615383, 339.74999999999994, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(772.6153846153845, 203.8499999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(944.3076923076923, 203.8499999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1030.1538461538462, 339.74999999999994, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# #### Thus our model is fit to make predictions for the iris dataset using Graphical tools.
#
# We will now define a function that takes the input and target variables as inputs and directly gives the predicted output based on the graphical representation. We will use the cancer diagnosis (Malignant / Benign classification) dataset to test the function.

# %%
import pandas as pd
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder as le
# %matplotlib inline
    
def dec_tree_graph(inputs, target):
    dec_tree = tree.DecisionTreeClassifier(random_state = 0)
    classifier = dec_tree.fit(inputs, target)
    plt.figure(figsize=(20,15))
    tree.plot_tree(classifier, filled = True)
    return tree.plot_tree(classifier, filled = True)

# %%
df = pd.read_csv('Malignant or Benign_ Cancer.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df['diagnosis'] = le.fit_transform(df['diagnosis'], df['diagnosis'])
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                0.14710  ...        25.380          17.33           184.60
# 1                0.07017  ...        24.990          23.41           158.80
# 2                0.12790  ...        23.570          25.53           152.50
# 3                0.10520  ...        14.910          26.50            98.87
# 4                0.10430  ...        22.540          16.67           152.20
# ..                   ...  ...           ...            ...              ...
# 564              0.13890  ...        25.450          26.40           166.10
# 565              0.09791  ...        23.690          38.25           155.00
# 566              0.05302  ...        18.980          34.12           126.70
# 567              0.15200  ...        25.740          39.42           184.60
# 568              0.00000  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
inputs = df.drop(df[['id', 'diagnosis']], axis = 1)
inputs
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %%
target = df[['diagnosis']]
target
# Out:
#      diagnosis
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 564          1
# 565          1
# 566          1
# 567          1
# 568          0
#
# [569 rows x 1 columns]

# %%
#We now pass the variables on the function to evaluate it.
dec_tree_graph(inputs, target)
# Out:
# [Text(697.5, 764.4375, 'X[20] <= 16.795\ngini = 0.468\nsamples = 569\nvalue = [357, 212]'),
#  Text(453.375, 662.5125, 'X[27] <= 0.136\ngini = 0.159\nsamples = 379\nvalue = [346, 33]'),
#  Text(261.5625, 560.5875, 'X[10] <= 1.048\ngini = 0.03\nsamples = 333\nvalue = [328, 5]'),
#  Text(226.6875, 458.66249999999997, 'X[13] <= 38.605\ngini = 0.024\nsamples = 332\nvalue = [328, 4]'),
#  Text(139.5, 356.7375, 'X[14] <= 0.003\ngini = 0.012\nsamples = 319\nvalue = [317, 2]'),
#  Text(69.75, 254.8125, 'X[26] <= 0.195\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(34.875, 152.88750000000005, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(104.625, 152.88750000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(209.25, 254.8125, 'X[21] <= 33.27\ngini = 0.006\nsamples = 312\nvalue = [311, 1]'),
#  Text(174.375, 152.88750000000005, 'gini = 0.0\nsamples = 292\nvalue = [292, 0]'),
#  Text(244.125, 152.88750000000005, 'X[21] <= 33.56\ngini = 0.095\nsamples = 20\nvalue = [19, 1]'),
#  Text(209.25, 50.96249999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(279.0, 50.96249999999998, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(313.875, 356.7375, 'X[13] <= 39.15\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(279.0, 254.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(348.75, 254.8125, 'X[25] <= 0.082\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(313.875, 152.88750000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(383.625, 152.88750000000005, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(296.4375, 458.66249999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(645.1875, 560.5875, 'X[21] <= 25.67\ngini = 0.476\nsamples = 46\nvalue = [18, 28]'),
#  Text(523.125, 458.66249999999997, 'X[23] <= 810.3\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(453.375, 356.7375, 'X[4] <= 0.123\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(418.5, 254.8125, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(488.25, 254.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(592.875, 356.7375, 'X[2] <= 92.79\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(558.0, 254.8125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(627.75, 254.8125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(767.25, 458.66249999999997, 'X[7] <= 0.054\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(732.375, 356.7375, 'X[21] <= 28.545\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(697.5, 254.8125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(767.25, 254.8125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(802.125, 356.7375, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(941.625, 662.5125, 'X[21] <= 19.91\ngini = 0.109\nsamples = 190\nvalue = [11, 179]'),
#  Text(871.875, 560.5875, 'X[15] <= 0.021\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(837.0, 458.66249999999997, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(906.75, 458.66249999999997, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1011.375, 560.5875, 'X[24] <= 0.088\ngini = 0.023\nsamples = 173\nvalue = [2, 171]'),
#  Text(976.5, 458.66249999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1046.25, 458.66249999999997, 'X[26] <= 0.18\ngini = 0.012\nsamples = 172\nvalue = [1, 171]'),
#  Text(1011.375, 356.7375, 'X[7] <= 0.041\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(976.5, 254.8125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1046.25, 254.8125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1081.125, 356.7375, 'gini = 0.0\nsamples = 168\nvalue = [0, 168]')]

# %% [markdown]
# ## RESULT:  Thus, our function can define and plot graphs for any classification based task and make suitable predictions. This can be done by feeding the inputs and target variables to the function, ONLY.
